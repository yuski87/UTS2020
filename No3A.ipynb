# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('H:/Ngampus lur/UAS/nomer3.txt',
                 delimiter=',')

# %%
df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian
# 0           0
# 1           1
# 2           0
# 3           0
# ...

# %%
import math 
dis = []
for i in range(80):
    dis.append(math.sqrt((float(df.iloc[i]['Usia'])-32)**2+
                         (float(df.iloc[i]['Kelahiran_ke-'])- 3)**2+
                         (float(df.iloc[i]['Waktu_Kelahiran'])-0)**2+
                         (float(df.iloc[i]['Tekanan_darah'])-2)**2))

# %%
df['dis'] = dis
df
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 0     22              1                0              2                 0
# 1     26              2                0              1                 0
# 2     26              2                1              1                 0
# 3     28              1                0              2                 0
# 4     22              2                0              1                 0
# ..   ...            ...              ...            ...               ...
# 75    27              2                1              1                 0
# 76    33              4                0              1                 0
# 77    29              2                1              2                 0
# 78    25              1                2              0                 0
# 79    24              2                2              1                 0
#
#     Caesarian        dis
# 0           0  10.198039
# 1           1   6.164414
# ...

# %%
df.sort_values('dis')
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 32    32              2                0              2                 1
# 73    32              3                0              1                 1
# 47    32              2                0              2                 1
# 7     32              3                0              1                 0
# 63    32              2                0              1                 1
# ..   ...            ...              ...            ...               ...
# 41    19              1                0              1                 0
# 61    19              1                0              1                 0
# 26    18              1                1              2                 1
# 25    18              1                0              1                 0
# 70    17              1                0              0                 0
#
#     Caesarian        dis
# 32          1   1.000000
# 73          0   1.000000
# ...

# %%
y = df.sort_values('dis').head(3)
y
# Out:
#     Usia  Kelahiran_ke-  Waktu_Kelahiran  Tekanan_darah  Kelainan_jantung  \
# 32    32              2                0              2                 1
# 73    32              3                0              1                 1
# 47    32              2                0              2                 1
#
#     Caesarian  dis
# 32          1  1.0
# 73          0  1.0
# 47          1  1.0

# %%
z = y["Caesarian"]
z
# Out:
# 32    1
# 73    0
# 47    1
# Name: Caesarian, dtype: int64

# %%
np.mean(z)
# Out:
# 0.6666666666666666
